# %%
import requests
import pandas
import os
from dotenv import load_dotenv

# %%
load_dotenv()

api_ID = os.getenv("api_ID")
api_key = os.getenv("api_key")

# %%
req = requests.get(f'https://api.adzuna.com/v1/api/jobs/br/search/1?app_id={api_ID}&app_key={api_key}&what=dados')

# %%
req.status_code
# Out:
# 200

# %%
data = req.json()

# %%
data['results']
# Out:
# [{'salary_is_predicted': '0',
#   '__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiS25tVzFkSl84UkdYcHR6d2d4aG9ndyIsImkiOiI1NzU4NzgxMjU0In0.v_fDCM9h_aaoBq2pFZQA0dXpedG8mvfA3lieL6Jp7Rg',
#   'location': {'area': ['Brasil',
#     'Sudeste',
#     'Estado de São Paulo',
#     'São Paulo'],
#    '__CLASS__': 'Adzuna::API::Response::Location',
#    'display_name': 'São Paulo, Estado de São Paulo'},
#   'redirect_url': 'https://www.adzuna.com.br/land/ad/5758781254?se=KnmW1dJ_8RGXptzwgxhogw&utm_medium=api&utm_source=be6e3fc6&v=79F4BF9940D542BB338BFFF1FD81BDA180164215',
#   'title': 'Arquiteto de Dados Sr.',
#   'id': '5758781254',
#   'created': '2026-06-10T17:36:26Z',
#   'category': {'label': 'Unknown',
#    '__CLASS__': 'Adzuna::API::Response::Category',
#    'tag': 'unknown'},
# ...
